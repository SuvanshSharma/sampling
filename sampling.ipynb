# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\OMEN\Desktop\Creditcard_data.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      1
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import normalize
Amount = normalize([df['Amount']])[0]
df['Amount'] = Amount
df = df.iloc[:, 1:]
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 1  0.167170  0.125895 -0.008983  0.014724  0.000463      1
# 2 -0.327642 -0.139097 -0.055353 -0.059752  0.065115      0
# 3  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 4 -0.206010  0.502292  0.219422  0.215153  0.012036      0
#
# [5 rows x 30 columns]

# %%
class_freq = df['Class'].value_counts()
print(f"Number of classes: {len(class_freq)}")
print("Class frequencies:")
print(class_freq)
# Out:
# Number of classes: 2
# Class frequencies:
# 0    763
# 1      9
# Name: Class, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

X = df.drop('Class', axis=1)
y = df['Class']

oversampler = RandomOverSampler()
undersampler = RandomUnderSampler()

X_over, y_over = oversampler.fit_resample(X, y)
X_resampled, y_resampled = undersampler.fit_resample(X_over, y_over)

print("Number of samples in each class after resampling:")
print(y_resampled.value_counts())
# Out:
# Number of samples in each class after resampling:
# 0    763
# 1    763
# Name: Class, dtype: int64

# %%
X_resampled
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1522 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1523 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1524  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 1525  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#             V8        V9       V10  ...       V20       V21       V22  \
# 0     0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838
# 1     0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679
# 2     0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274
# 3    -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278
# 4     0.260314 -0.568671 -0.371407  ...  0.084968 -0.208254 -0.559825
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521 -0.202836  0.035154 -0.282617  ... -0.079756 -0.287592 -0.832682
# 1522 -0.067794 -0.270953 -0.838587  ...  2.102339  0.661696  0.435477
# 1523  1.391657 -2.770089 -2.772272  ...  0.126911  0.517232 -0.035049
# 1524  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672
# 1525  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672
#
#            V23       V24       V25       V26       V27       V28    Amount
# 0    -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729
# 1     0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  0.065115
# 2    -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237
# 3    -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153  0.012036
# 4    -0.026398 -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  0.128083  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463
# 1522  1.375966 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968
# 1523 -0.465211  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000
# 1524  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463
# 1525  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463
#
# [1526 rows x 29 columns]

# %%
new_df = pd.concat([X_resampled, y_resampled], axis=1)
new_df
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1522 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1523 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1524  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 1525  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 1     0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 2     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 3    -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
# 4     0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 1522 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1523  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 1524  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
# 1525  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
#
#            V24       V25       V26       V27       V28    Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 1    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  0.065115      0
# 2    -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 3     0.141267 -0.206010  0.502292  0.219422  0.215153  0.012036      0
# 4    -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1521  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 1522 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1523  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
# 1524 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463      1
# 1525 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463      1
#
# [1526 rows x 30 columns]

# %%
class_freq = new_df['Class'].value_counts()
print(f"Number of classes: {len(class_freq)}")
print("Class frequencies:")
print(class_freq)
# Out:
# Number of classes: 2
# Class frequencies:
# 0    763
# 1    763
# Name: Class, dtype: int64

# %%
n = int((1.96*1.96 * 0.5*0.5)/(0.05**2))
sampled_df = new_df.sample(n=n, random_state=42)
print(sampled_df)
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 1439  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 76    0.921544 -0.067084  0.077461  0.953638  0.067412  0.016152  0.320452
# 1010 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 660   0.074738 -3.032009 -0.429919 -0.442721 -1.784710 -0.066668  0.098736
# 1132  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480  0.296319
# ...        ...       ...       ...       ...       ...       ...       ...
# 1481  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 756  -1.062129 -0.618574  0.615388 -3.335834  0.746649 -0.540531  0.705932
# 1074 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262 -2.110183
# 867   0.073497  0.551033  0.451890  0.114964  0.822947  0.251480  0.296319
# 485   1.106251  0.398625  0.860421  2.388862 -0.365843 -0.192568 -0.121769
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 1439 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 76    0.038534 -0.391513  0.031560  ... -0.333930 -1.299920  0.084311
# 1010 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 660  -0.222525 -0.241858  0.158664  ... -0.078927 -1.247242 -0.620402
# 1132  0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932  0.151012
# ...        ...       ...       ...  ...       ...       ...       ...
# 1481 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 756   0.032525  1.334181 -2.326389  ... -0.114269 -0.661122  0.136250
# 1074  0.788347  0.958809 -0.328631  ...  0.422452  1.195394  0.297836
# 867   0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932  0.151012
# 485   0.150876 -0.733271  0.860900  ... -0.253189 -0.952836  0.181643
#
#            V24       V25       V26       V27       V28    Amount  Class
# 1439  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 76   -0.370398  0.155102 -0.834490  0.000909  0.035547  0.023303      0
# 1010 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 660  -0.368545 -0.073359  1.296835 -0.192760  0.121440  0.122578      0
# 1132 -1.363967 -1.389079  0.075412  0.231750  0.230171  0.000170      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 1481  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 756  -1.377245  0.263820 -1.115516  0.079213  0.116638  0.022591      0
# 1074 -0.857105 -0.219322  0.861019 -0.124622 -0.171060  0.000258      1
# 867  -1.363967 -1.389079  0.075412  0.231750  0.230171  0.000170      1
# 485   0.222462  0.083552 -0.342278 -0.017021  0.020976  0.002997      0
#
# [384 rows x 30 columns]

# %%
interval = 2
systematic_df = new_df.iloc[::interval]
systematic_df
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6    -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8    -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# ...        ...       ...       ...       ...       ...       ...       ...
# 1516 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1518 -0.928088  0.398194  1.741131  0.182673  0.966387 -0.901004  0.879016
# 1520  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1522 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1524  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 2     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 4     0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398
# 6    -3.807864  0.615375  1.249376  ...  1.943465 -1.015455  0.057504
# 8     0.069539 -0.736727 -0.366846  ... -0.246914 -0.633753 -0.120794
# ...        ...       ...       ...  ...       ...       ...       ...
# 1516 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1518 -0.156590 -0.142117 -0.574775  ...  0.066353  0.281378 -0.257966
# 1520 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 1522 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1524  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
#
#            V24       V25       V26       V27       V28    Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 2    -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 4    -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631      0
# 6    -0.649709 -0.415267 -0.051634 -1.206921 -1.085339  0.007016      0
# 8    -0.385050 -0.069733  0.094199  0.246219  0.083076  0.000633      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1516 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1518  0.385384  0.391117 -0.453853 -0.104448 -0.125765  0.000172      1
# 1520  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 1522 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1524 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463      1
#
# [763 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

n = int((1.96*1.96 * 0.5*0.5)/((0.05)**2))

strata = new_df.groupby('Class')

stratified_df = strata.apply(lambda x: x.sample(n))

stratified_df
# Out:
#                   V1        V2        V3        V4        V5        V6  \
# Class
# 0     639  -0.932349  0.789123  0.534111  1.140724 -0.448967 -0.288526
#       474   1.135846  0.084164  0.269573  1.210034  0.005128  0.318050
#       721  -1.274193  1.722263  0.429337  0.105932 -0.732006 -1.107861
#       6    -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
#       83    1.202398  0.321711  0.281211  0.643689 -0.148669 -0.589739
# ...              ...       ...       ...       ...       ...       ...
# 1     772  -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262
#       1412  1.257719  0.364739  0.306923  0.690638 -0.357792 -1.067481
#       788  -1.738582  0.052740  1.187057 -0.656652  0.920623 -0.291788
#       1290  0.073497  0.551033  0.451890  0.114964  0.822947  0.251480
#       1243 -2.000567 -2.495484  2.467149  1.140053  2.462010  0.594262
#
#                   V7        V8        V9       V10  ...       V21       V22  \
# Class                                               ...
# 0     639   1.072543  0.118515 -0.152883 -0.033482  ...  0.092532  0.662627
#       474  -0.082664  0.191049  0.157573  0.062804  ... -0.076927 -0.063246
#       721  -0.021279  0.818796 -0.447669 -0.638642  ... -0.218749 -0.786584
#       6     1.120631 -3.807864  0.615375  1.249376  ...  1.943465 -1.015455
#       83    0.048413 -0.093361 -0.042934 -0.343246  ... -0.251113 -0.680155
# ...              ...       ...       ...       ...  ...       ...       ...
# 1     772  -2.110183  0.788347  0.958809 -0.328631  ...  0.422452  1.195394
#       1412  0.094272 -0.210300  0.014455 -0.286012  ... -0.286856 -0.820658
#       788   0.269083  0.140631  0.023464 -0.066407  ... -0.179545 -0.192036
#       1290  0.296319  0.139497 -0.123050 -0.142617  ... -0.128758 -0.381932
#       1243 -2.110183  0.788347  0.958809 -0.328631  ...  0.422452  1.195394
#
#                  V23       V24       V25       V26       V27       V28  \
# Class
# 0     639   0.319256  0.397955 -0.454037 -0.338746  0.134917 -0.094342
#       474  -0.110678 -0.306079  0.651983 -0.308067  0.030276  0.001831
#       721   0.106722  0.313637 -0.083626  0.083494  0.109637  0.018247
#       6     0.057504 -0.649709 -0.415267 -0.051634 -1.206921 -1.085339
#       83    0.148163  0.047062  0.157050  0.121935 -0.004608  0.029418
# ...              ...       ...       ...       ...       ...       ...
# 1     772   0.297836 -0.857105 -0.219322  0.861019 -0.124622 -0.171060
#       1412  0.127663  0.343128  0.221120  0.094391 -0.022189  0.030944
#       788  -0.261879 -0.237477 -0.335040  0.240323 -0.345129 -0.383563
#       1290  0.151012 -1.363967 -1.389079  0.075412  0.231750  0.230171
#       1243  0.297836 -0.857105 -0.219322  0.861019 -0.124622 -0.171060
#
#               Amount  Class
# Class
# 0     639   0.024032      0
#       474   0.002213      0
#       721   0.002894      0
#       6     0.007016      0
#       83    0.001295      0
# ...              ...    ...
# 1     772   0.000258      1
#       1412  0.000222      1
#       788   0.000172      1
#       1290  0.000170      1
#       1243  0.000258      1
#
# [768 rows x 30 columns]

# %%
import numpy as np

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=42).fit(new_df)
cluster_assignments = kmeans.labels_

selected_clusters = [0, 2, 4, 5, 8]

cluster_series = pd.Series(cluster_assignments)

df_cluster_sample = new_df[cluster_series.isin(selected_clusters)]

(df_cluster_sample)
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 17   -5.401258 -5.450148  1.186305  1.736239  3.049106 -1.763406 -1.559738
# 25    1.173285  0.353498  0.283905  1.133563 -0.172577 -0.916054  0.369025
# 53    1.295668  0.341483  0.081505  0.566746 -0.110459 -0.766325  0.073155
# 58    1.154312  0.265462  0.384871  0.575007 -0.217475 -0.391520 -0.081489
# 59    0.986063 -0.202965 -0.492768  0.407691  0.305660 -0.230529  0.585028
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1522 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1523 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1524  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 1525  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 17    0.160842  1.233090  0.345173  ... -0.503600  0.984460  2.458589
# 25   -0.327260 -0.246651 -0.046139  ...  0.067003  0.227812 -0.150487
# 53   -0.168304  0.071837 -0.281044  ... -0.323607 -0.929781  0.063809
# 58    0.062789 -0.260583 -0.161677  ... -0.193213 -0.557685  0.169492
# 59   -0.208225 -0.247503 -0.192253  ... -0.305874 -1.216555 -0.077602
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 1522 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1523  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 1524  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
# 1525  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
#
#            V24       V25       V26       V27       V28    Amount  Class
# 17    0.042119 -0.481631 -0.621272  0.392053  0.949594  0.008048      0
# 25    0.435045  0.724825 -0.337082  0.016368  0.030041  0.007202      0
# 53   -0.193565  0.287574  0.127881 -0.023731  0.025200  0.000170      0
# 58    0.186863  0.089252  0.093626 -0.009633  0.019668  0.000459      0
# 59   -0.741341  0.286881  0.200347 -0.075203  0.027271  0.029070      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1521  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 1522 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1523  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
# 1524 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463      1
# 1525 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463      1
#
# [651 rows x 30 columns]

# %%
convenience_sample = pd.concat([new_df.head(380), new_df.tail(380)])
convenience_sample
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 2    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4    -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# ...        ...       ...       ...       ...       ...       ...       ...
# 1521  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256  0.086781
# 1522 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 1523 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1524  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 1525  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 1     0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 2     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 3    -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
# 4     0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398
# ...        ...       ...       ...  ...       ...       ...       ...
# 1521 -0.202836  0.035154 -0.282617  ... -0.287592 -0.832682  0.128083
# 1522 -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 1523  1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 1524  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
# 1525  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
#
#            V24       V25       V26       V27       V28    Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  0.025729      0
# 1    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  0.065115      0
# 2    -1.175575  0.647376 -0.221929  0.062723  0.061458  0.021237      0
# 3     0.141267 -0.206010  0.502292  0.219422  0.215153  0.012036      0
# 4    -0.371427 -0.232794  0.105915  0.253844  0.081080  0.000631      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1521  0.339427  0.215944  0.094704 -0.023354  0.030892  0.000463      1
# 1522 -0.293803  0.279798 -0.145362 -0.252773  0.035764  0.090968      1
# 1523  0.320198  0.044519  0.177840  0.261145 -0.143276  0.000000      1
# 1524 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463      1
# 1525 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.000463      1
#
# [760 rows x 30 columns]

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\omen\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: seaborn in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.11.2)
# Requirement already satisfied: wordcloud in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.8.2.2)
# Requirement already satisfied: ipywidgets in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: numpy>=1.17 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: IPython in c:\users\omen\appdata\roaming\python\python39\site-packages (from pycaret) (8.3.0)
# Requirement already satisfied: imbalanced-learn>=0.7.0 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: cufflinks>=0.17.0 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.17.3)
# Requirement already satisfied: kmodes>=0.10.1 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: matplotlib in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (3.5.1)
# Requirement already satisfied: joblib in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: pandas-profiling>=2.8.0 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (3.6.6)
# Requirement already satisfied: textblob in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: pandas in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: spacy in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: mlflow in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: plotly>=4.4.1 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (5.6.0)
# Requirement already satisfied: pyLDAvis in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (3.3.1)
# Requirement already satisfied: pyod in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.0.7)
# Requirement already satisfied: gensim in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (4.1.2)
# Requirement already satisfied: mlxtend in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.21.0)
# Requirement already satisfied: scikit-plot in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: umap-learn in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (0.5.3)
# Requirement already satisfied: lightgbm>=2.3.1 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.7.4)
# Requirement already satisfied: catboost>=0.23.2 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.1.1)
# Requirement already satisfied: yellowbrick>=1.0.1 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: nltk in c:\users\omen\anaconda3\lib\site-packages (from pycaret) (3.7)
# Requirement already satisfied: six in c:\users\omen\appdata\roaming\python\python39\site-packages (from catboost>=0.23.2->pycaret) (1.16.0)
# Requirement already satisfied: scipy in c:\users\omen\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.7.3)
# Requirement already satisfied: graphviz in c:\users\omen\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (0.20.1)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\omen\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (61.2.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\omen\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (0.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\omen\anaconda3\lib\site-packages (from imbalanced-learn>=0.7.0->pycaret) (2.2.0)
# Requirement already satisfied: pickleshare in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: decorator in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.18.1)
# Requirement already satisfied: colorama in c:\users\omen\anaconda3\lib\site-packages (from IPython->pycaret) (0.4.6)
# Requirement already satisfied: matplotlib-inline in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (2.12.0)
# Requirement already satisfied: traitlets>=5 in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (5.2.0)
# Requirement already satisfied: backcall in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\omen\appdata\roaming\python\python39\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\omen\appdata\roaming\python\python39\site-packages (from ipywidgets->pycaret) (6.13.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\omen\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\omen\anaconda3\lib\site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\omen\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\omen\anaconda3\lib\site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: psutil in c:\users\omen\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\omen\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.6.0)
# Requirement already satisfied: nest-asyncio in c:\users\omen\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\omen\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (7.3.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\omen\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: packaging in c:\users\omen\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (21.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\omen\appdata\roaming\python\python39\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\omen\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret) (2.8.2)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\omen\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret) (22.3.0)
# Requirement already satisfied: entrypoints in c:\users\omen\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\omen\appdata\roaming\python\python39\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret) (4.10.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\omen\appdata\roaming\python\python39\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret) (304)
# Requirement already satisfied: wheel in c:\users\omen\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.1)
# Requirement already satisfied: fastjsonschema in c:\users\omen\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\omen\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\omen\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\omen\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omen\anaconda3\lib\site-packages (from pandas->pycaret) (2021.3)
# Requirement already satisfied: ydata-profiling in c:\users\omen\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\omen\anaconda3\lib\site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\omen\appdata\roaming\python\python39\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\omen\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\omen\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.4)
# Requirement already satisfied: jinja2 in c:\users\omen\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\omen\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\omen\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\omen\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\omen\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\omen\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.0.2)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\omen\anaconda3\lib\site-packages (from yellowbrick>=1.0.1->pycaret) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\omen\appdata\roaming\python\python39\site-packages (from matplotlib->pycaret) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\omen\anaconda3\lib\site-packages (from matplotlib->pycaret) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\omen\anaconda3\lib\site-packages (from matplotlib->pycaret) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\omen\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.3.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\omen\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\omen\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\omen\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.21)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\omen\anaconda3\lib\site-packages (from gensim->pycaret) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\omen\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.0.1)
# Requirement already satisfied: Flask<3 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (8.0.4)
# Requirement already satisfied: alembic<2 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (1.9.4)
# Requirement already satisfied: shap<1,>=0.40 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (0.41.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (6.0)
# Requirement already satisfied: cloudpickle<3 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (3.19.1)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (3.3.4)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (2.27.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (4.11.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (0.4.3)
# Requirement already satisfied: querystring-parser<2 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (1.2.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (3.1.31)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (0.17.4)
# Requirement already satisfied: waitress<3 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (2.1.2)
# Requirement already satisfied: pyarrow<11,>=4.0.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (10.0.1)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.32)
# Requirement already satisfied: docker<7,>=4.0.0 in c:\users\omen\anaconda3\lib\site-packages (from mlflow->pycaret) (6.0.1)
# Requirement already satisfied: Mako in c:\users\omen\anaconda3\lib\site-packages (from alembic<2->mlflow->pycaret) (1.2.4)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\omen\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\omen\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (0.8.9)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\omen\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (2.1.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\omen\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (1.26.9)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\omen\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (0.58.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\omen\anaconda3\lib\site-packages (from Flask<3->mlflow->pycaret) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\omen\anaconda3\lib\site-packages (from Flask<3->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\omen\anaconda3\lib\site-packages (from gitpython<4,>=2.1.0->mlflow->pycaret) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\omen\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->pycaret) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\omen\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow->pycaret) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\omen\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow->pycaret) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\omen\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\omen\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow->pycaret) (3.3)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\omen\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow->pycaret) (4.64.0)
# Requirement already satisfied: numba in c:\users\omen\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow->pycaret) (0.55.1)
# Requirement already satisfied: slicer==0.0.7 in c:\users\omen\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow->pycaret) (0.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\omen\anaconda3\lib\site-packages (from sqlalchemy<2,>=1.4.0->mlflow->pycaret) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: testpath in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.11.1)
# Requirement already satisfied: bleach in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\omen\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\omen\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\omen\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\omen\anaconda3\lib\site-packages (from nltk->pycaret) (2022.3.15)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\omen\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow->pycaret) (0.38.0)
# Requirement already satisfied: sklearn in c:\users\omen\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.0)
# Requirement already satisfied: funcy in c:\users\omen\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (1.18)
# Requirement already satisfied: numexpr in c:\users\omen\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (2.8.1)
# Requirement already satisfied: future in c:\users\omen\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: statsmodels in c:\users\omen\anaconda3\lib\site-packages (from pyod->pycaret) (0.13.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (2.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (3.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (1.1.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (1.10.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (8.1.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\omen\anaconda3\lib\site-packages (from spacy->pycaret) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\omen\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy->pycaret) (4.5.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\omen\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->pycaret) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\omen\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->pycaret) (0.0.4)
# Requirement already satisfied: pure-eval in c:\users\omen\appdata\roaming\python\python39\site-packages (from stack-data->IPython->pycaret) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\omen\appdata\roaming\python\python39\site-packages (from stack-data->IPython->pycaret) (2.0.5)
# Requirement already satisfied: executing in c:\users\omen\appdata\roaming\python\python39\site-packages (from stack-data->IPython->pycaret) (0.8.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\omen\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\omen\anaconda3\lib\site-packages (from umap-learn->pycaret) (0.5.8)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\omen\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.7.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\omen\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.1.12)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\omen\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (1.9.1)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\omen\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.12.3)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\omen\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret) (2.13.3)
# Requirement already satisfied: networkx>=2.4 in c:\users\omen\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (2.7.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\omen\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (0.2.0)
# Requirement already satisfied: imagehash in c:\users\omen\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (4.3.1)
# Requirement already satisfied: PyWavelets in c:\users\omen\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret) (1.3.0)

# %%
from pycaret.classification import *

setup(data = sampled_df, target='Class', silent=True,fold_shuffle=True)
cm = compare_models()
# Out:
# <style type="text/css">
# </style>
# <table id="T_38c0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38c0b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_38c0b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38c0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38c0b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_38c0b_row0_col1" class="data row0 col1" >6681</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38c0b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_38c0b_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38c0b_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_38c0b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38c0b_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_38c0b_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38c0b_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_38c0b_row4_col1" class="data row4 col1" >(384, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38c0b_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_38c0b_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38c0b_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_38c0b_row6_col1" class="data row6 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38c0b_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_38c0b_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_38c0b_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_38c0b_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_38c0b_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_38c0b_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_38c0b_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_38c0b_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_38c0b_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_38c0b_row11_col1" class="data row11 col1" >(268, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_38c0b_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_38c0b_row12_col1" class="data row12 col1" >(116, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_38c0b_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_38c0b_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_38c0b_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_38c0b_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_38c0b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_38c0b_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_38c0b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_38c0b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_38c0b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_38c0b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_38c0b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_38c0b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_38c0b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_38c0b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_38c0b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_38c0b_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_38c0b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_38c0b_row21_col1" class="data row21 col1" >7f92</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_38c0b_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_38c0b_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_38c0b_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_38c0b_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_38c0b_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_38c0b_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_38c0b_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_38c0b_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_38c0b_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_38c0b_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_38c0b_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_38c0b_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_38c0b_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_38c0b_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_38c0b_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_38c0b_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38c0b_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_38c0b_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_38c0b_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 3>()
#       1 from pycaret.classification import *
# ----> 3 setup(data = sampled_df, target='Class', silent=True,fold_shuffle=True)
#       4 cm = compare_models()
#
# File ~\anaconda3\lib\site-packages\pycaret\classification.py:580, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     577 if log_plots == True:
#     578     log_plots = ["auc", "confusion_matrix", "feature"]
# --> 580 return pycaret.internal.tabular.setup(
#     581     ml_usecase="classification",
#     582     available_plots=available_plots,
#     583     data=data,
#     584     target=target,
#     585     train_size=train_size,
#     586     test_data=test_data,
#     587     preprocess=preprocess,
#     588     imputation_type=imputation_type,
#     589     iterative_imputation_iters=iterative_imputation_iters,
#     590     categorical_features=categorical_features,
#     591     categorical_imputation=categorical_imputation,
#     592     categorical_iterative_imputer=categorical_iterative_imputer,
#     593     ordinal_features=ordinal_features,
#     594     high_cardinality_features=high_cardinality_features,
#     595     high_cardinality_method=high_cardinality_method,
#     596     numeric_features=numeric_features,
#     597     numeric_imputation=numeric_imputation,
#     598     numeric_iterative_imputer=numeric_iterative_imputer,
#     599     date_features=date_features,
#     600     ignore_features=ignore_features,
#     601     normalize=normalize,
#     602     normalize_method=normalize_method,
#     603     transformation=transformation,
#     604     transformation_method=transformation_method,
#     605     handle_unknown_categorical=handle_unknown_categorical,
#     606     unknown_categorical_method=unknown_categorical_method,
#     607     pca=pca,
#     608     pca_method=pca_method,
#     609     pca_components=pca_components,
#     610     ignore_low_variance=ignore_low_variance,
#     611     combine_rare_levels=combine_rare_levels,
#     612     rare_level_threshold=rare_level_threshold,
#     613     bin_numeric_features=bin_numeric_features,
#     614     remove_outliers=remove_outliers,
#     615     outliers_threshold=outliers_threshold,
#     616     remove_multicollinearity=remove_multicollinearity,
#     617     multicollinearity_threshold=multicollinearity_threshold,
#     618     remove_perfect_collinearity=remove_perfect_collinearity,
#     619     create_clusters=create_clusters,
#     620     cluster_iter=cluster_iter,
#     621     polynomial_features=polynomial_features,
#     622     polynomial_degree=polynomial_degree,
#     623     trigonometry_features=trigonometry_features,
#     624     polynomial_threshold=polynomial_threshold,
#     625     group_features=group_features,
#     626     group_names=group_names,
#     627     feature_selection=feature_selection,
#     628     feature_selection_threshold=feature_selection_threshold,
#     629     feature_selection_method=feature_selection_method,
#     630     feature_interaction=feature_interaction,
#     631     feature_ratio=feature_ratio,
#     632     interaction_threshold=interaction_threshold,
#     633     fix_imbalance=fix_imbalance,
#     634     fix_imbalance_method=fix_imbalance_method,
#     635     data_split_shuffle=data_split_shuffle,
#     636     data_split_stratify=data_split_stratify,
#     637     fold_strategy=fold_strategy,
#     638     fold=fold,
#     639     fold_shuffle=fold_shuffle,
#     640     fold_groups=fold_groups,
#     641     n_jobs=n_jobs,
#     642     use_gpu=use_gpu,
#     643     custom_pipeline=custom_pipeline,
#     644     html=html,
#     645     session_id=session_id,
#     646     log_experiment=log_experiment,
#     647     experiment_name=experiment_name,
#     648     log_plots=log_plots,
#     649     log_profile=log_profile,
#     650     log_data=log_data,
#     651     silent=silent,
#     652     verbose=verbose,
#     653     profile=profile,
#     654     profile_kwargs=profile_kwargs,
#     655 )
#
# File ~\anaconda3\lib\site-packages\pycaret\internal\tabular.py:1745, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1742 logger.info(f"master_model_container: {len(master_model_container)}")
#    1743 logger.info(f"display_container: {len(display_container)}")
# -> 1745 logger.info(str(prep_pipe))
#    1746 logger.info("setup() succesfully completed......................................")
#    1748 gc.collect()
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:279, in BaseEstimator.__repr__(self, N_CHAR_MAX)
#     271 # use ellipsis for sequences with a lot of elements
#     272 pp = _EstimatorPrettyPrinter(
#     273     compact=True,
#     274     indent=1,
#     275     indent_at_name=True,
#     276     n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW,
#     277 )
# --> 279 repr_ = pp.pformat(self)
#     281 # Use bruteforce ellipsis when there are a lot of non-blank characters
#     282 n_nonblank = len("".join(repr_.split()))
#
# File ~\anaconda3\lib\pprint.py:153, in PrettyPrinter.pformat(self, object)
#     151 def pformat(self, object):
#     152     sio = _StringIO()
# --> 153     self._format(object, sio, 0, 0, {}, 0)
#     154     return sio.getvalue()
#
# File ~\anaconda3\lib\pprint.py:170, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     168     self._readable = False
#     169     return
# --> 170 rep = self._repr(object, context, level)
#     171 max_width = self._width - indent - allowance
#     172 if len(rep) > max_width:
#
# File ~\anaconda3\lib\pprint.py:431, in PrettyPrinter._repr(self, object, context, level)
#     430 def _repr(self, object, context, level):
# --> 431     repr, readable, recursive = self.format(object, context.copy(),
#     432                                             self._depth, level)
#     433     if not readable:
#     434         self._readable = False
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py:189, in _EstimatorPrettyPrinter.format(self, object, context, maxlevels, level)
#     188 def format(self, object, context, maxlevels, level):
# --> 189     return _safe_repr(
#     190         object, context, maxlevels, level, changed_only=self._changed_only
#     191     )
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py:452, in _safe_repr(object, context, maxlevels, level, changed_only)
#     448 for k, v in items:
#     449     krepr, kreadable, krecur = saferepr(
#     450         k, context, maxlevels, level, changed_only=changed_only
#     451     )
# --> 452     vrepr, vreadable, vrecur = saferepr(
#     453         v, context, maxlevels, level, changed_only=changed_only
#     454     )
#     455     append("%s=%s" % (krepr.strip("'"), vrepr))
#     456     readable = readable and kreadable and vreadable
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py:442, in _safe_repr(object, context, maxlevels, level, changed_only)
#     440     params = _changed_params(object)
#     441 else:
# --> 442     params = object.get_params(deep=False)
#     443 components = []
#     444 append = components.append
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:210, in BaseEstimator.get_params(self, deep)
#     208 out = dict()
#     209 for key in self._get_param_names():
# --> 210     value = getattr(self, key)
#     211     if deep and hasattr(value, "get_params"):
#     212         deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
from pycaret.classification import *

setup(data = systematic_df, target='Class', silent=True)
cm = compare_models()

# %%
setup(data = stratified_df, target='Class', silent=True)
cm = compare_models()

# %%
setup(data = df_cluster_sample, target='Class', silent=True)
cm = compare_models()

# %%
setup(data = convenience_sample, target='Class', silent=True)
cm = compare_models()
